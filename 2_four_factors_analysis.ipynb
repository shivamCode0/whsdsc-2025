# %%
import pandas as pd
import numpy as np

# Basketball-specific constants
FOUR_FACTOR_WEIGHTS = {
    'shooting': 0.35,  # Reduced from 0.4
    'turnovers': 0.3,   # Increased from 0.25
    'rebounding': 0.25, # Increased from 0.2
    'free_throws': 0.1  # Reduced from 0.15
}

# Load data with absolute paths to prevent leaks
game_data = pd.read_csv('games_2022.csv')
teams_regions = pd.read_csv('Team Region Groups.csv')

# %%
def calculate_possessions(group):
    """Calculate possessions using NCAA formula"""
    group['possessions'] = group['FGA_2'] + group['FGA_3'] + 0.44 * group['FTA'] - group['OREB'] + group['TOV_team']
    return group

# Process games with True Possessions
games = game_data.groupby('game_id', group_keys=False).apply(calculate_possessions)

# %%
def team_efficiency_metrics(df):
    """Calculate season-long Four Factors metrics"""
    agg_stats = df.groupby('team').agg({
        'FGM_2': 'sum',
        'FGA_2': 'sum',
        'FGM_3': 'sum', 
        'FGA_3': 'sum',
        'OREB': 'sum',
        'DREB': 'sum',
        'TOV_team': 'mean',
        'FTA': 'sum',
        'team_score': 'mean',
        'possessions': 'sum'
    })
    
    # Four Factors Calculations
    agg_stats['eFG%'] = (agg_stats['FGM_2'] + 1.5*agg_stats['FGM_3']) / (agg_stats['FGA_2'] + agg_stats['FGA_3'])
    agg_stats['TOV%'] = agg_stats['TOV_team'] / agg_stats['possessions']
    agg_stats['ORB%'] = agg_stats['OREB'] / (agg_stats['OREB'] + agg_stats['DREB'])
    agg_stats['FTRate'] = agg_stats['FTA'] / (agg_stats['FGA_2'] + agg_stats['FGA_3'])
    
    return agg_stats

team_stats = team_efficiency_metrics(games)

# Composite Four Factors Score
team_stats['Composite'] = (
    FOUR_FACTOR_WEIGHTS['shooting'] * team_stats['eFG%'] +
    FOUR_FACTOR_WEIGHTS['turnovers'] * (1 - team_stats['TOV%']) +
    FOUR_FACTOR_WEIGHTS['rebounding'] * team_stats['ORB%'] +
    FOUR_FACTOR_WEIGHTS['free_throws'] * team_stats['FTRate']
)

# Merge with regions
team_rankings = pd.merge(
    team_stats.reset_index(),
    teams_regions,
    on='team', how='inner'
)

# Generate regional rankings
for region in ['North', 'South', 'West']:
    region_teams = team_rankings[team_rankings['region'] == region] \
        .sort_values('Composite', ascending=False) \
        .head(16) \
        [['team', 'Composite']]
    
    print(f"\n--- {region} Region Rankings ---")
    print(region_teams.round(3))
# Out:
# --- North Region Rankings ---
#                              team  Composite
# 49      jackson_state_lady_tigers      0.592
# 108    stephen_f_austin_ladyjacks      0.590
# 112  tennessee_tech_golden_eagles      0.589
# 99       south_carolina_gamecocks      0.585
# 34        georgia_southern_eagles      0.584
# 11                 belmont_bruins      0.582
# 3            alabama_crimson_tide      0.581
# 30           freed_hardeman_lions      0.580
# 89                ole_miss_rebels      0.578
# 94                      rice_owls      0.577
# 105     southern_miss_lady_eagles      0.577
# 28      florida_gulf_coast_eagles      0.577
# 125                   ucf_knights      0.575
# 63                     lsu_tigers      0.575
# 32   gardner_webb_runnin_bulldogs      0.574
# 119             tulane_green_wave      0.574
#
# --- South Region Rankings ---
#                               team  Composite
# 23              depaul_blue_demons      0.592
# 134  western_kentucky_lady_toppers      0.591
# 70             michigan_wolverines      0.589
# 76             murray_state_racers      0.585
# 8            austin_peay_governors      0.585
# 46                   iowa_hawkeyes      0.584
# 61            louisville_cardinals      0.582
# 16         cleveland_state_vikings      0.582
# 69         michigan_state_spartans      0.580
# 48         iu_indianapolis_jaguars      0.580
# 56               kentucky_wildcats      0.579
# 24                  drake_bulldogs      0.579
# 87             ohio_state_buckeyes      0.578
# 104      southern_illinois_salukis      0.578
# 52                kansas_city_roos      0.578
# 47             iowa_state_cyclones      0.575
#
# --- West Region Rankings ---
#                                team  Composite
# 130                       utah_utes      0.595
# 115                 texas_longhorns      0.594
# 0        abilene_christian_wildcats      0.593
# 12                      byu_cougars      0.589
# 36                 gonzaga_bulldogs      0.588
# 77             nebraska_cornhuskers      0.587
# 107               stanford_cardinal      0.585
# 95                san_diego_toreros      0.584
# 20               creighton_bluejays      0.583
# 102  south_dakota_state_jackrabbits      0.583
# 10                     baylor_bears      0.583
# 88                 oklahoma_sooners      0.582
# 92                  portland_pilots      0.582
# 128                unlv_lady_rebels      0.582
# 6                  arizona_wildcats      0.581
# 37               grand_canyon_lopes      0.577
# C:\Users\shiva\AppData\Local\Temp\ipykernel_31176\1662589198.py:41: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   games = game_data.groupby('game_id', group_keys=False).apply(calculate_possessions)

# %%
# %% [markdown]
# ## Phase 1b: Four Factors Predictions

# %%
east_matchups = pd.read_csv('East Regional Games to predict.csv')

def matchup_predictor(row):
    """Calculate winning probability using Four Factors comparison"""
    home_team = team_stats.loc[row['team_home']]
    away_team = team_stats.loc[row['team_away']]
    
    # Four Factors Differential
    shooting_diff = home_team['eFG%'] - away_team['eFG%']
    tov_diff = away_team['TOV%'] - home_team['TOV%']  # Higher opponent TOV% is better
    orb_diff = home_team['ORB%'] - away_team['ORB%']
    ft_diff = home_team['FTRate'] - away_team['FTRate']
    
    # Weighted Advantage Score
    raw_score = (
        FOUR_FACTOR_WEIGHTS['shooting'] * shooting_diff +
        FOUR_FACTOR_WEIGHTS['turnovers'] * tov_diff +
        FOUR_FACTOR_WEIGHTS['rebounding'] * orb_diff +
        FOUR_FACTOR_WEIGHTS['free_throws'] * ft_diff
    )
    
    # Replace logistic scaling
    base_prob = 0.5 + (raw_score * 0.8)  # Tuned multiplier
    base_prob = np.clip(base_prob, 0.2, 0.8)
    
    # Contextual Adjustments
    rest_adj = 0.03 * (row['rest_days_Home'] - row['rest_days_Away'])
    travel_adj = -0.02 * (row['travel_dist_Away'] / 500)
    neutral_adj = 0.05 if row['home_away_NS'] == 0 else 0
    
    adj_score = base_prob + rest_adj + travel_adj + neutral_adj
    
    # Logistic conversion to probability
    # return round(1 / (1 + np.exp(-adj_score*10)), 4)  # Scaled for proper probability distribution
    return adj_score

# Generate predictions
east_matchups['WINNING %'] = east_matchups.apply(matchup_predictor, axis=1)
# east_matchups['WINNING %'] = east_matchups['WINNING %'].clip(0.01, 0.99)

# Validate and export
print("\nFinal Predictions:")
print(east_matchups[['game_id', 'team_home', 'team_away', 'WINNING %']])
# east_matchups.to_csv('FourFactors_predictions.csv', index=False)

# %% [markdown]
# ## Validation Suite
# Out:
# Final Predictions:
#      game_id                   team_home                 team_away  WINNING %
# 0   G_East_1           rhode_island_rams  north_carolina_tar_heels   0.663934
# 1   G_East_2           nc_state_wolfpack         rhode_island_rams   0.737499
# 2   G_East_3           nc_state_wolfpack  north_carolina_tar_heels   0.701433
# 3   G_East_4              liberty_flames            bucknell_bison   0.477245
# 4   G_East_5              drexel_dragons        delaware_blue_hens   0.576590
# 5   G_East_6   massachusetts_minutewomen          princeton_tigers   0.615532
# 6   G_East_7               buffalo_bulls     stony_brook_seawolves   0.420689
# 7   G_East_8             fairfield_stags             towson_tigers   0.467475
# 8   G_East_9               uconn_huskies  campbell_fighting_camels   0.443326
# 9  G_East_10  american_university_eagles            columbia_lions   0.498138

# %%
# %%
# Backtest on Regular Season
# %% [markdown]
# ## Validation Suite (Fixed Backtest)

def get_opponent_stats(game_row, full_data):
    """Retrieve opponent's stats from the same game_id"""
    game_id = game_row.name  # Using index with game_id
    game_group = full_data[full_data['game_id'] == game_id]
    return game_group[game_group['team'] != game_row['team']].iloc[0]

# Sample complete games (both opponents)
unique_games = games['game_id'].unique()
sampled_game_ids = np.random.choice(unique_games, 500, replace=False)
sample_games = games[games['game_id'].isin(sampled_game_ids)]

# Create paired records
predictions = []
for game_id, game_group in sample_games.groupby('game_id'):
    home_teams = game_group[game_group['home_away_NS'] == 1]
    away_teams = game_group[game_group['home_away_NS'] == -1]
    
    # Skip if we don't have both home and away teams
    if home_teams.empty or away_teams.empty:
        print(f"Skipping {game_id} - missing home or away team")
        continue
        
    home_team = home_teams.iloc[0]
    away_team = away_teams.iloc[0]
    
    try:
        pred = matchup_predictor(pd.Series({
            'team_home': home_team['team'],
            'team_away': away_team['team'],
            'rest_days_Home': home_team['rest_days'],
            'rest_days_Away': away_team['rest_days'],
            'travel_dist_Away': away_team['travel_dist'],
            'home_away_NS': 1  # Proper home/away context
        }))
        
        actual_winner_home = home_team['team_score'] > away_team['team_score']
        predictions.append({
            'pred': pred,
            'actual': actual_winner_home
        })
        print(f"Processed {game_id}: Home - {home_team['team']} vs Away - {away_team['team']}")
    except Exception as e:
        print(f"Skipping {game_id} due to error: {str(e)}")

# Calculate metrics
pred_df = pd.DataFrame(predictions)
# Fix the comparison by using parentheses to properly group operations
print(f"\nValidation Accuracy: {((pred_df['pred'] > 0.5) == pred_df['actual']).mean():.2%}")
print(f"Brier Score: {((pred_df['pred'] - pred_df['actual'].astype(float))**2).mean():.3f}")
# Out:
# Processed game_2022_1001: Home - creighton_bluejays vs Away - northern_iowa_panthers
# Skipping game_2022_1005 - missing home or away team
# Processed game_2022_1035: Home - stony_brook_seawolves vs Away - st_francis_brooklyn_terriers
# Processed game_2022_1047: Home - oral_roberts_golden_eagles vs Away - little_rock_trojans
# Skipping game_2022_1061 - missing home or away team
# Skipping game_2022_1069 - missing home or away team
# Processed game_2022_1076: Home - providence_friars vs Away - monmouth_hawks
# Processed game_2022_1085: Home - alabama_state_lady_hornets vs Away - south_alabama_jaguars
# Processed game_2022_1103: Home - ohio_bobcats vs Away - florida_am_rattlers
# Processed game_2022_1139: Home - ualbany_great_danes vs Away - bryant_bulldogs
# Processed game_2022_1147: Home - quinnipiac_bobcats vs Away - yale_bulldogs
# Processed game_2022_1148: Home - buffalo_bulls vs Away - niagara_purple_eagles
# Processed game_2022_1149: Home - presbyterian_blue_hose vs Away - unc_greensboro_spartans
# Processed game_2022_1157: Home - wichita_state_shockers vs Away - oral_roberts_golden_eagles
# Skipping game_2022_116 - missing home or away team
# Processed game_2022_1169: Home - cal_state_northridge_matadors vs Away - loyola_marymount_lions
# Processed game_2022_117: Home - niagara_purple_eagles vs Away - loyola_maryland_greyhounds
# Processed game_2022_1170: Home - texas_longhorns vs Away - jackson_state_lady_tigers
# Skipping game_2022_1171 - missing home or away team
# Processed game_2022_1174: Home - winthrop_eagles vs Away - unc_wilmington_seahawks
# Processed game_2022_118: Home - navy_midshipmen vs Away - georgetown_hoyas
# Processed game_2022_1181: Home - villanova_wildcats vs Away - lehigh_mountain_hawks
# Processed game_2022_1188: Home - virginia_cavaliers vs Away - william_mary_tribe
# Skipping game_2022_119 - missing home or away team
# Processed game_2022_12: Home - florida_international_panthers vs Away - george_mason_patriots
# Processed game_2022_1203: Home - montana_lady_griz vs Away - sacramento_state_hornets
# Processed game_2022_1207: Home - arkansas_state_red_wolves vs Away - northwestern_state_lady_demons
# Processed game_2022_1210: Home - uc_santa_barbara_gauchos vs Away - denver_pioneers
# Processed game_2022_1220: Home - california_golden_bears vs Away - fresno_state_bulldogs
# Processed game_2022_1228: Home - navy_midshipmen vs Away - morgan_state_lady_bears
# Processed game_2022_1273: Home - delaware_state_hornets vs Away - saint_peters_peacocks
# Processed game_2022_1288: Home - detroit_mercy_titans vs Away - uic_flames
# Skipping game_2022_129 - missing home or away team
# Processed game_2022_1294: Home - portland_pilots vs Away - oregon_ducks
# Processed game_2022_1301: Home - st_francis_pa_red_flash vs Away - la_salle_explorers
# Processed game_2022_1302: Home - ohio_bobcats vs Away - richmond_spiders
# Processed game_2022_1306: Home - loyola_maryland_greyhounds vs Away - mount_st_marys_mountaineers
# Skipping game_2022_1316 - missing home or away team
# Skipping game_2022_1317 - missing home or away team
# Processed game_2022_1331: Home - north_carolina_tar_heels vs Away - james_madison_dukes
# Processed game_2022_1352: Home - kentucky_wildcats vs Away - merrimack_warriors
# Processed game_2022_1359: Home - fordham_rams vs Away - princeton_tigers
# Skipping game_2022_138 - missing home or away team
# Skipping game_2022_1380 - missing home or away team
# Processed game_2022_1385: Home - providence_friars vs Away - georgetown_hoyas
# Skipping game_2022_1386 - missing home or away team
# Processed game_2022_1394: Home - george_mason_patriots vs Away - norfolk_state_spartans
# Processed game_2022_1409: Home - liberty_flames vs Away - virginia_tech_hokies
# Skipping game_2022_1412 - missing home or away team
# Processed game_2022_1418: Home - siu_edwardsville_cougars vs Away - western_illinois_leathernecks
# Processed game_2022_1423: Home - oklahoma_sooners vs Away - eastern_michigan_eagles
# Skipping game_2022_1425 - missing home or away team
# Processed game_2022_1428: Home - pennsylvania_quakers vs Away - saint_josephs_hawks
# Processed game_2022_143: Home - arizona_wildcats vs Away - cal_state_northridge_matadors
# Processed game_2022_1430: Home - ohio_state_buckeyes vs Away - mount_st_marys_mountaineers
# Processed game_2022_1456: Home - detroit_mercy_titans vs Away - western_michigan_broncos
# Processed game_2022_1462: Home - iowa_state_cyclones vs Away - iowa_hawkeyes
# Processed game_2022_1472: Home - loyola_maryland_greyhounds vs Away - morgan_state_lady_bears
# Skipping game_2022_150 - missing home or away team
# Skipping game_2022_1507 - missing home or away team
# Processed game_2022_1511: Home - portland_state_vikings vs Away - pepperdine_waves
# Processed game_2022_1515: Home - butler_bulldogs vs Away - denver_pioneers
# Processed game_2022_1517: Home - lamar_cardinals vs Away - texas_state_bobcats
# Skipping game_2022_1526 - missing home or away team
# Processed game_2022_1536: Home - providence_friars vs Away - quinnipiac_bobcats
# Processed game_2022_1569: Home - drexel_dragons vs Away - longwood_lancers
# Processed game_2022_1578: Home - ohio_state_buckeyes vs Away - indiana_hoosiers
# Processed game_2022_1587: Home - notre_dame_fighting_irish vs Away - purdue_fort_wayne_mastodons
# Skipping game_2022_159 - missing home or away team
# Processed game_2022_1597: Home - app_state_mountaineers vs Away - wofford_terriers
# Processed game_2022_1623: Home - james_madison_dukes vs Away - west_virginia_mountaineers
# Processed game_2022_1626: Home - st_bonaventure_bonnies vs Away - marshall_thundering_herd
# Processed game_2022_1627: Home - old_dominion_monarchs vs Away - norfolk_state_spartans
# Processed game_2022_1631: Home - wagner_seahawks vs Away - st_johns_red_storm
# Processed game_2022_1637: Home - arizona_wildcats vs Away - new_mexico_lobos
# Processed game_2022_1639: Home - tennessee_lady_volunteers vs Away - georgia_state_panthers
# Skipping game_2022_1671 - missing home or away team
# Processed game_2022_168: Home - cornell_big_red vs Away - colgate_raiders
# Skipping game_2022_1684 - missing home or away team
# Processed game_2022_17: Home - iowa_hawkeyes vs Away - new_hampshire_wildcats
# Skipping game_2022_1700 - missing home or away team
# Processed game_2022_1712: Home - louisville_cardinals vs Away - eastern_kentucky_colonels
# Processed game_2022_1726: Home - wisconsin_badgers vs Away - illinois_state_redbirds
# Skipping game_2022_1732 - missing home or away team
# Processed game_2022_174: Home - drake_bulldogs vs Away - creighton_bluejays
# Processed game_2022_1751: Home - syracuse_orange vs Away - umbc_retrievers
# Skipping game_2022_1755 - missing home or away team
# Processed game_2022_1763: Home - fairfield_stags vs Away - marist_red_foxes
# Processed game_2022_1781: Home - kansas_state_wildcats vs Away - oregon_ducks
# Processed game_2022_1793: Home - gardner_webb_runnin_bulldogs vs Away - austin_peay_governors
# Processed game_2022_18: Home - stony_brook_seawolves vs Away - delaware_state_hornets
# Skipping game_2022_1803 - missing home or away team
# Processed game_2022_1805: Home - lsu_tigers vs Away - bradley_braves
# Processed game_2022_1808: Home - florida_state_seminoles vs Away - virginia_tech_hokies
# Skipping game_2022_1818 - missing home or away team
# Processed game_2022_1824: Home - kentucky_wildcats vs Away - south_carolina_upstate_spartans
# Skipping game_2022_1843 - missing home or away team
# Processed game_2022_187: Home - eastern_washington_eagles vs Away - san_jose_state_spartans
# Skipping game_2022_1877 - missing home or away team
# Processed game_2022_1893: Home - illinois_state_redbirds vs Away - saint_louis_billikens
# Processed game_2022_1904: Home - charleston_southern_buccaneers vs Away - duke_blue_devils
# Processed game_2022_1917: Home - unlv_lady_rebels vs Away - hawaii_rainbow_wahine
# Processed game_2022_1922: Home - florida_gators vs Away - murray_state_racers
# Processed game_2022_1941: Home - coppin_state_eagles vs Away - maryland_terrapins
# Skipping game_2022_1942 - missing home or away team
# Skipping game_2022_1946 - missing home or away team
# Processed game_2022_195: Home - iowa_hawkeyes vs Away - samford_bulldogs
# Processed game_2022_1952: Home - depaul_blue_demons vs Away - notre_dame_fighting_irish
# Processed game_2022_1957: Home - unc_greensboro_spartans vs Away - unc_wilmington_seahawks
# Processed game_2022_1961: Home - kansas_city_roos vs Away - south_dakota_coyotes
# Processed game_2022_1970: Home - hartford_hawks vs Away - massachusetts_minutewomen
# Processed game_2022_1983: Home - fresno_state_bulldogs vs Away - unlv_lady_rebels
# Skipping game_2022_1985 - missing home or away team
# Processed game_2022_1997: Home - north_carolina_at_aggies vs Away - longwood_lancers
# Processed game_2022_1998: Home - unc_asheville_bulldogs vs Away - radford_highlanders
# Processed game_2022_2010: Home - baylor_bears vs Away - north_texas_mean_green
# Processed game_2022_204: Home - tulsa_golden_hurricane vs Away - duquesne_dukes
# Processed game_2022_2046: Home - utsa_roadrunners vs Away - middle_tennessee_blue_raiders
# Processed game_2022_2058: Home - st_johns_red_storm vs Away - brown_bears
# Skipping game_2022_2071 - missing home or away team
# Processed game_2022_2072: Home - washington_state_cougars vs Away - california_golden_bears
# Processed game_2022_2078: Home - central_michigan_chippewas vs Away - northern_illinois_huskies
# Processed game_2022_2079: Home - ul_monroe_warhawks vs Away - ut_arlington_mavericks
# Processed game_2022_2085: Home - weber_state_wildcats vs Away - montana_lady_griz
# Processed game_2022_2106: Home - morehead_state_eagles vs Away - tennessee_state_lady_tigers
# Skipping game_2022_2110 - missing home or away team
# Processed game_2022_2111: Home - alabama_crimson_tide vs Away - auburn_tigers
# Processed game_2022_2116: Home - indiana_hoosiers vs Away - maryland_terrapins
# Processed game_2022_2127: Home - duke_blue_devils vs Away - notre_dame_fighting_irish
# Processed game_2022_2129: Home - stony_brook_seawolves vs Away - hartford_hawks
# Processed game_2022_2133: Home - brown_bears vs Away - pennsylvania_quakers
# Processed game_2022_2136: Home - princeton_tigers vs Away - harvard_crimson
# Processed game_2022_2150: Home - grambling_lady_tigers vs Away - prairie_view_am_lady_panthers
# Processed game_2022_2157: Home - bowling_green_falcons vs Away - buffalo_bulls
# Processed game_2022_2159: Home - toledo_rockets vs Away - eastern_michigan_eagles
# Processed game_2022_2160: Home - central_michigan_chippewas vs Away - western_michigan_broncos
# Processed game_2022_2163: Home - oklahoma_state_cowgirls vs Away - kansas_state_wildcats
# Processed game_2022_2181: Home - mississippi_valley_state_devilettes vs Away - alabama_am_bulldogs
# Processed game_2022_2187: Home - southern_jaguars vs Away - prairie_view_am_lady_panthers
# Processed game_2022_2189: Home - alabama_crimson_tide vs Away - mississippi_state_bulldogs
# Processed game_2022_2199: Home - maryland_terrapins vs Away - penn_state_lady_lions
# Processed game_2022_2221: Home - purdue_fort_wayne_mastodons vs Away - oakland_golden_grizzlies
# Processed game_2022_2223: Home - merrimack_warriors vs Away - fairleigh_dickinson_knights
# Processed game_2022_2225: Home - st_francis_pa_red_flash vs Away - st_francis_brooklyn_terriers
# Processed game_2022_2226: Home - belmont_bruins vs Away - southeast_missouri_state_redhawks
# Processed game_2022_2233: Home - evansville_purple_aces vs Away - bradley_braves
# Processed game_2022_2234: Home - loyola_chicago_ramblers vs Away - drake_bulldogs
# Processed game_2022_2245: Home - eastern_michigan_eagles vs Away - central_michigan_chippewas
# Skipping game_2022_225 - missing home or away team
# Processed game_2022_226: Home - cincinnati_bearcats vs Away - bellarmine_knights
# Processed game_2022_2269: Home - uc_irvine_anteaters vs Away - uc_riverside_highlanders
# Processed game_2022_2278: Home - north_dakota_state_bison vs Away - omaha_mavericks
# Processed game_2022_228: Home - marquette_golden_eagles vs Away - njit_highlanders
# Processed game_2022_2308: Home - prairie_view_am_lady_panthers vs Away - mississippi_valley_state_devilettes
# Processed game_2022_2315: Home - georgia_lady_bulldogs vs Away - alabama_crimson_tide
# Processed game_2022_2316: Home - ole_miss_rebels vs Away - tennessee_lady_volunteers
# Processed game_2022_2317: Home - mississippi_state_bulldogs vs Away - vanderbilt_commodores
# Processed game_2022_233: Home - lehigh_mountain_hawks vs Away - saint_peters_peacocks
# Processed game_2022_2332: Home - northeastern_huskies vs Away - hofstra_pride
# Processed game_2022_2341: Home - clemson_tigers vs Away - boston_college_eagles
# Processed game_2022_2345: Home - jacksonville_dolphins vs Away - florida_gulf_coast_eagles
# Processed game_2022_2356: Home - fordham_rams vs Away - la_salle_explorers
# Processed game_2022_236: Home - furman_paladins vs Away - presbyterian_blue_hose
# Processed game_2022_2364: Home - alabama_am_bulldogs vs Away - jackson_state_lady_tigers
# Processed game_2022_2372: Home - denver_pioneers vs Away - oral_roberts_golden_eagles
# Processed game_2022_2375: Home - stephen_f_austin_ladyjacks vs Away - abilene_christian_wildcats
# Processed game_2022_241: Home - ucf_knights vs Away - tennessee_lady_volunteers
# Processed game_2022_2425: Home - vanderbilt_commodores vs Away - tennessee_lady_volunteers
# Processed game_2022_2428: Home - indiana_hoosiers vs Away - nebraska_cornhuskers
# Processed game_2022_2432: Home - san_diego_state_aztecs vs Away - utah_state_aggies
# Processed game_2022_2440: Home - pacific_tigers vs Away - gonzaga_bulldogs
# Processed game_2022_2441: Home - santa_clara_broncos vs Away - pepperdine_waves
# Processed game_2022_2442: Home - byu_cougars vs Away - saint_marys_gaels
# Processed game_2022_2451: Home - louisville_cardinals vs Away - syracuse_orange
# Processed game_2022_2458: Home - uc_santa_barbara_gauchos vs Away - long_beach_state_beach
# Processed game_2022_2474: Home - chicago_state_cougars vs Away - ut_rio_grande_valley_vaqueros
# Processed game_2022_2489: Home - murray_state_racers vs Away - tennessee_state_lady_tigers
# Processed game_2022_2492: Home - san_jose_state_spartans vs Away - fresno_state_bulldogs
# Processed game_2022_251: Home - oklahoma_sooners vs Away - arkansas_state_red_wolves
# Processed game_2022_2511: Home - unlv_lady_rebels vs Away - utah_state_aggies
# Processed game_2022_2523: Home - south_alabama_jaguars vs Away - louisiana_ragin_cajuns
# Processed game_2022_2532: Home - texas_longhorns vs Away - west_virginia_mountaineers
# Processed game_2022_2533: Home - drake_bulldogs vs Away - missouri_state_lady_bears
# Processed game_2022_2552: Home - winthrop_eagles vs Away - gardner_webb_runnin_bulldogs
# Processed game_2022_2556: Home - cal_state_northridge_matadors vs Away - long_beach_state_beach
# Processed game_2022_2562: Home - western_carolina_catamounts vs Away - mercer_bears
# Processed game_2022_2568: Home - st_thomas_minnesota_tommies vs Away - north_dakota_fighting_hawks
# Processed game_2022_2571: Home - omaha_mavericks vs Away - south_dakota_coyotes
# Processed game_2022_2588: Home - st_francis_brooklyn_terriers vs Away - wagner_seahawks
# Processed game_2022_2604: Home - alcorn_state_lady_braves vs Away - texas_southern_tigers
# Processed game_2022_2608: Home - mississippi_valley_state_devilettes vs Away - bethune_cookman_wildcats
# Processed game_2022_2609: Home - holy_cross_crusaders vs Away - colgate_raiders
# Processed game_2022_2610: Home - oregon_ducks vs Away - arizona_wildcats
# Processed game_2022_2617: Home - texas_am_aggies vs Away - auburn_tigers
# Processed game_2022_2618: Home - penn_state_lady_lions vs Away - illinois_fighting_illini
# Processed game_2022_2623: Home - rutgers_scarlet_knights vs Away - wisconsin_badgers
# Processed game_2022_2642: Home - ucf_knights vs Away - south_florida_bulls
# Processed game_2022_2648: Home - utah_utes vs Away - stanford_cardinal
# Processed game_2022_2649: Home - usc_trojans vs Away - washington_huskies
# Processed game_2022_266: Home - rutgers_scarlet_knights vs Away - south_alabama_jaguars
# Skipping game_2022_267 - missing home or away team
# Processed game_2022_2676: Home - umass_lowell_river_hawks vs Away - umbc_retrievers
# Processed game_2022_2680: Home - louisiana_tech_lady_techsters vs Away - utsa_roadrunners
# Processed game_2022_2689: Home - unc_asheville_bulldogs vs Away - high_point_panthers
# Processed game_2022_2691: Home - delaware_blue_hens vs Away - james_madison_dukes
# Processed game_2022_2706: Home - eastern_michigan_eagles vs Away - western_michigan_broncos
# Processed game_2022_2727: Home - massachusetts_minutewomen vs Away - dayton_flyers
# Processed game_2022_2734: Home - houston_cougars vs Away - cincinnati_bearcats
# Processed game_2022_274: Home - umass_lowell_river_hawks vs Away - bryant_bulldogs
# Processed game_2022_2773: Home - northern_colorado_bears vs Away - idaho_vandals
# Processed game_2022_2774: Home - montana_lady_griz vs Away - portland_state_vikings
# Processed game_2022_2778: Home - uc_riverside_highlanders vs Away - cal_state_northridge_matadors
# Processed game_2022_2790: Home - new_orleans_privateers vs Away - se_louisiana_lady_lions
# Processed game_2022_2799: Home - ut_rio_grande_valley_vaqueros vs Away - utah_valley_wolverines
# Processed game_2022_2813: Home - murray_state_racers vs Away - eastern_illinois_panthers
# Processed game_2022_2818: Home - columbia_lions vs Away - cornell_big_red
# Processed game_2022_2827: Home - iu_indianapolis_jaguars vs Away - uic_flames
# Processed game_2022_2842: Home - davidson_wildcats vs Away - fordham_rams
# Processed game_2022_2859: Home - texas_state_bobcats vs Away - ut_arlington_mavericks
# Processed game_2022_2886: Home - campbell_fighting_camels vs Away - radford_highlanders
# Processed game_2022_2903: Home - samford_bulldogs vs Away - furman_paladins
# Processed game_2022_2910: Home - north_dakota_fighting_hawks vs Away - kansas_city_roos
# Processed game_2022_2911: Home - south_dakota_coyotes vs Away - st_thomas_minnesota_tommies
# Processed game_2022_2926: Home - tulane_green_wave vs Away - wichita_state_shockers
# Processed game_2022_2928: Home - south_florida_bulls vs Away - temple_owls
# Processed game_2022_2940: Home - tennessee_state_lady_tigers vs Away - austin_peay_governors
# Processed game_2022_2961: Home - rutgers_scarlet_knights vs Away - ohio_state_buckeyes
# Processed game_2022_2965: Home - charleston_cougars vs Away - james_madison_dukes
# Processed game_2022_2970: Home - georgia_tech_yellow_jackets vs Away - north_carolina_tar_heels
# Processed game_2022_2988: Home - xavier_musketeers vs Away - depaul_blue_demons
# Processed game_2022_3035: Home - high_point_panthers vs Away - longwood_lancers
# Processed game_2022_3038: Home - wichita_state_shockers vs Away - east_carolina_pirates
# Processed game_2022_3046: Home - toledo_rockets vs Away - ohio_bobcats
# Processed game_2022_3056: Home - new_hampshire_wildcats vs Away - maine_black_bears
# Processed game_2022_3064: Home - st_bonaventure_bonnies vs Away - la_salle_explorers
# Processed game_2022_3079: Home - wyoming_cowgirls vs Away - boise_state_broncos
# Processed game_2022_3081: Home - unc_wilmington_seahawks vs Away - delaware_blue_hens
# Processed game_2022_3084: Home - depaul_blue_demons vs Away - uconn_huskies
# Processed game_2022_3090: Home - vanderbilt_commodores vs Away - kentucky_wildcats
# Processed game_2022_3100: Home - georgia_state_panthers vs Away - south_alabama_jaguars
# Processed game_2022_311: Home - southern_miss_lady_eagles vs Away - ul_monroe_warhawks
# Processed game_2022_3117: Home - virginia_cavaliers vs Away - virginia_tech_hokies
# Processed game_2022_3123: Home - florida_gulf_coast_eagles vs Away - eastern_kentucky_colonels
# Processed game_2022_313: Home - michigan_wolverines vs Away - st_francis_brooklyn_terriers
# Processed game_2022_3130: Home - cal_state_bakersfield_roadrunners vs Away - uc_irvine_anteaters
# Skipping game_2022_315 - missing home or away team
# Processed game_2022_3161: Home - st_francis_brooklyn_terriers vs Away - sacred_heart_pioneers
# Processed game_2022_3174: Home - south_carolina_gamecocks vs Away - ole_miss_rebels
# Processed game_2022_3180: Home - loyola_chicago_ramblers vs Away - valparaiso_beacons
# Processed game_2022_3201: Home - miami_oh_redhawks vs Away - eastern_michigan_eagles
# Processed game_2022_3206: Home - georgia_southern_eagles vs Away - south_alabama_jaguars
# Processed game_2022_3207: Home - louisiana_ragin_cajuns vs Away - ul_monroe_warhawks
# Processed game_2022_3221: Home - bradley_braves vs Away - northern_iowa_panthers
# Processed game_2022_3231: Home - umbc_retrievers vs Away - binghamton_bearcats
# Processed game_2022_3245: Home - cal_poly_mustangs vs Away - uc_irvine_anteaters
# Processed game_2022_3255: Home - northwestern_state_lady_demons vs Away - texas_am_corpus_christi_islanders
# Processed game_2022_3305: Home - lsu_tigers vs Away - kentucky_wildcats
# Processed game_2022_3308: Home - vanderbilt_commodores vs Away - auburn_tigers
# Processed game_2022_3309: Home - penn_state_lady_lions vs Away - maryland_terrapins
# Processed game_2022_3312: Home - minnesota_golden_gophers vs Away - wisconsin_badgers
# Processed game_2022_3324: Home - maine_black_bears vs Away - vermont_catamounts
# Processed game_2022_3325: Home - saint_louis_billikens vs Away - richmond_spiders
# Skipping game_2022_3352 - missing home or away team
# Processed game_2022_3353: Home - kansas_city_roos vs Away - western_illinois_leathernecks
# Processed game_2022_3359: Home - ucf_knights vs Away - temple_owls
# Processed game_2022_3378: Home - uic_flames vs Away - northern_kentucky_norse
# Processed game_2022_3404: Home - longwood_lancers vs Away - charleston_southern_buccaneers
# Processed game_2022_3406: Home - tulsa_golden_hurricane vs Away - houston_cougars
# Processed game_2022_3441: Home - central_arkansas_sugar_bears vs Away - florida_gulf_coast_eagles
# Processed game_2022_346: Home - ole_miss_rebels vs Away - mississippi_valley_state_devilettes
# Processed game_2022_3476: Home - purdue_fort_wayne_mastodons vs Away - northern_kentucky_norse
# Processed game_2022_3479: Home - bryant_bulldogs vs Away - st_francis_pa_red_flash
# Processed game_2022_3505: Home - drake_bulldogs vs Away - valparaiso_beacons
# Processed game_2022_3509: Home - iu_indianapolis_jaguars vs Away - oakland_golden_grizzlies
# Processed game_2022_3511: Home - harvard_crimson vs Away - brown_bears
# Processed game_2022_3550: Home - dayton_flyers vs Away - george_mason_patriots
# Processed game_2022_356: Home - air_force_falcons vs Away - colorado_buffaloes
# Processed game_2022_3572: Home - high_point_panthers vs Away - winthrop_eagles
# Processed game_2022_358: Home - montana_lady_griz vs Away - gonzaga_bulldogs
# Processed game_2022_3589: Home - houston_christian_huskies vs Away - se_louisiana_lady_lions
# Processed game_2022_3595: Home - ut_rio_grande_valley_vaqueros vs Away - abilene_christian_wildcats
# Processed game_2022_360: Home - kansas_state_wildcats vs Away - western_kentucky_lady_toppers
# Processed game_2022_3601: Home - purdue_fort_wayne_mastodons vs Away - wright_state_raiders
# Processed game_2022_3605: Home - harvard_crimson vs Away - yale_bulldogs
# Processed game_2022_3611: Home - merrimack_warriors vs Away - st_francis_pa_red_flash
# Processed game_2022_363: Home - santa_clara_broncos vs Away - nevada_wolf_pack
# Processed game_2022_3634: Home - holy_cross_crusaders vs Away - army_black_knights
# Processed game_2022_3644: Home - minnesota_golden_gophers vs Away - michigan_state_spartans
# Processed game_2022_3651: Home - hofstra_pride vs Away - northeastern_huskies
# Processed game_2022_3659: Home - illinois_state_redbirds vs Away - indiana_state_sycamores
# Processed game_2022_3668: Home - saint_josephs_hawks vs Away - davidson_wildcats
# Processed game_2022_367: Home - rhode_island_rams vs Away - coppin_state_eagles
# Processed game_2022_3684: Home - utah_utes vs Away - washington_state_cougars
# Processed game_2022_3703: Home - delaware_state_hornets vs Away - howard_bison
# Processed game_2022_3721: Home - pacific_tigers vs Away - san_diego_toreros
# Processed game_2022_3725: Home - portland_pilots vs Away - loyola_marymount_lions
# Processed game_2022_3729: Home - gonzaga_bulldogs vs Away - san_francisco_dons
# Processed game_2022_3736: Home - virginia_tech_hokies vs Away - clemson_tigers
# Processed game_2022_3737: Home - northern_iowa_panthers vs Away - evansville_purple_aces
# Processed game_2022_3748: Home - wyoming_cowgirls vs Away - san_jose_state_spartans
# Processed game_2022_3749: Home - colorado_state_rams vs Away - utah_state_aggies
# Processed game_2022_3753: Home - bowling_green_falcons vs Away - northern_illinois_huskies
# Processed game_2022_3764: Home - jacksonville_dolphins vs Away - eastern_kentucky_colonels
# Processed game_2022_3768: Home - maine_black_bears vs Away - ualbany_great_danes
# Processed game_2022_3775: Home - cincinnati_bearcats vs Away - smu_mustangs
# Skipping game_2022_378 - missing home or away team
# Processed game_2022_3780: Home - american_university_eagles vs Away - bucknell_bison
# Processed game_2022_3783: Home - loyola_maryland_greyhounds vs Away - holy_cross_crusaders
# Processed game_2022_3796: Home - arkansas_razorbacks vs Away - auburn_tigers
# Processed game_2022_3801: Home - ohio_state_buckeyes vs Away - nebraska_cornhuskers
# Processed game_2022_3810: Home - pacific_tigers vs Away - san_francisco_dons
# Processed game_2022_3821: Home - weber_state_wildcats vs Away - eastern_washington_eagles
# Processed game_2022_3824: Home - uc_santa_barbara_gauchos vs Away - cal_state_bakersfield_roadrunners
# Processed game_2022_3838: Home - south_dakota_coyotes vs Away - omaha_mavericks
# Processed game_2022_3843: Home - grand_canyon_lopes vs Away - utah_valley_wolverines
# Processed game_2022_3862: Home - nicholls_colonels vs Away - incarnate_word_cardinals
# Processed game_2022_3872: Home - missouri_state_lady_bears vs Away - drake_bulldogs
# Processed game_2022_3873: Home - southern_illinois_salukis vs Away - northern_iowa_panthers
# Processed game_2022_3883: Home - creighton_bluejays vs Away - xavier_musketeers
# Skipping game_2022_389 - missing home or away team
# Processed game_2022_3893: Home - san_jose_state_spartans vs Away - colorado_state_rams
# Processed game_2022_3898: Home - northern_illinois_huskies vs Away - buffalo_bulls
# Processed game_2022_3911: Home - loyola_marymount_lions vs Away - santa_clara_broncos
# Processed game_2022_3931: Home - saint_louis_billikens vs Away - davidson_wildcats
# Processed game_2022_3958: Home - north_dakota_fighting_hawks vs Away - western_illinois_leathernecks
# Processed game_2022_3961: Home - south_dakota_state_jackrabbits vs Away - omaha_mavericks
# Processed game_2022_3969: Home - wright_state_raiders vs Away - uic_flames
# Processed game_2022_3997: Home - indiana_hoosiers vs Away - michigan_state_spartans
# Processed game_2022_4005: Home - rutgers_scarlet_knights vs Away - penn_state_lady_lions
# Processed game_2022_4011: Home - southern_illinois_salukis vs Away - drake_bulldogs
# Processed game_2022_4040: Home - arizona_wildcats vs Away - arizona_state_sun_devils
# Processed game_2022_4053: Home - kansas_city_roos vs Away - st_thomas_minnesota_tommies
# Processed game_2022_406: Home - youngstown_state_penguins vs Away - akron_zips
# Processed game_2022_4065: Home - umbc_retrievers vs Away - stony_brook_seawolves
# Processed game_2022_4070: Home - vermont_catamounts vs Away - ualbany_great_danes
# Processed game_2022_4071: Home - new_mexico_state_aggies vs Away - stephen_f_austin_ladyjacks
# Processed game_2022_4075: Home - uic_flames vs Away - detroit_mercy_titans
# Processed game_2022_4090: Home - kansas_jayhawks vs Away - west_virginia_mountaineers
# Processed game_2022_4093: Home - pepperdine_waves vs Away - pacific_tigers
# Processed game_2022_4103: Home - ohio_bobcats vs Away - toledo_rockets
# Processed game_2022_4104: Home - texas_longhorns vs Away - iowa_state_cyclones
# Processed game_2022_4112: Home - duquesne_dukes vs Away - richmond_spiders
# Processed game_2022_4133: Home - colgate_raiders vs Away - army_black_knights
# Processed game_2022_4137: Home - butler_bulldogs vs Away - providence_friars
# Processed game_2022_4142: Home - alabama_crimson_tide vs Away - tennessee_lady_volunteers
# Processed game_2022_4154: Home - colorado_state_rams vs Away - wyoming_cowgirls
# Processed game_2022_4165: Home - nc_state_wolfpack vs Away - wake_forest_demon_deacons
# Processed game_2022_4167: Home - syracuse_orange vs Away - virginia_tech_hokies
# Processed game_2022_4190: Home - western_carolina_catamounts vs Away - east_tennessee_state_bucs
# Processed game_2022_4196: Home - western_illinois_leathernecks vs Away - south_dakota_state_jackrabbits
# Processed game_2022_4221: Home - tennessee_tech_golden_eagles vs Away - southeast_missouri_state_redhawks
# Processed game_2022_423: Home - austin_peay_governors vs Away - north_alabama_lions
# Processed game_2022_4246: Home - oregon_state_beavers vs Away - stanford_cardinal
# Processed game_2022_4255: Home - bowling_green_falcons vs Away - ohio_bobcats
# Processed game_2022_4258: Home - northern_illinois_huskies vs Away - western_michigan_broncos
# Processed game_2022_4264: Home - arkansas_state_red_wolves vs Away - little_rock_trojans
# Processed game_2022_4284: Home - umbc_retrievers vs Away - vermont_catamounts
# Skipping game_2022_429 - missing home or away team
# Processed game_2022_4293: Home - high_point_panthers vs Away - charleston_southern_buccaneers
# Processed game_2022_4297: Home - unc_asheville_bulldogs vs Away - south_carolina_upstate_spartans
# Processed game_2022_4306: Home - quinnipiac_bobcats vs Away - niagara_purple_eagles
# Processed game_2022_4312: Home - nicholls_colonels vs Away - houston_christian_huskies
# Processed game_2022_4318: Home - denver_pioneers vs Away - omaha_mavericks
# Processed game_2022_432: Home - grand_canyon_lopes vs Away - eastern_washington_eagles
# Processed game_2022_4349: Home - north_carolina_central_eagles vs Away - delaware_state_hornets
# Processed game_2022_436: Home - ole_miss_rebels vs Away - lamar_cardinals
# Processed game_2022_4360: Home - florida_am_rattlers vs Away - alabama_state_lady_hornets
# Processed game_2022_4366: Home - cal_state_fullerton_titans vs Away - cal_state_northridge_matadors
# Processed game_2022_437: Home - auburn_tigers vs Away - alabama_state_lady_hornets
# Processed game_2022_4375: Home - michigan_wolverines vs Away - maryland_terrapins
# Processed game_2022_4378: Home - ohio_state_buckeyes vs Away - wisconsin_badgers
# Processed game_2022_4384: Home - elon_phoenix vs Away - northeastern_huskies
# Processed game_2022_4388: Home - evansville_purple_aces vs Away - loyola_chicago_ramblers
# Processed game_2022_4392: Home - virginia_cavaliers vs Away - pittsburgh_panthers
# Processed game_2022_4393: Home - clemson_tigers vs Away - duke_blue_devils
# Processed game_2022_4419: Home - southern_utah_thunderbirds vs Away - northern_arizona_lumberjacks
# Processed game_2022_4421: Home - howard_bison vs Away - coppin_state_eagles
# Processed game_2022_4423: Home - arkansas_pine_bluff_golden_lions vs Away - texas_southern_tigers
# Processed game_2022_4446: Home - georgetown_hoyas vs Away - villanova_wildcats
# Processed game_2022_445: Home - navy_midshipmen vs Away - william_mary_tribe
# Processed game_2022_4457: Home - buffalo_bulls vs Away - ohio_bobcats
# Processed game_2022_4472: Home - davidson_wildcats vs Away - george_washington_revolutionaries
# Processed game_2022_4481: Home - south_carolina_upstate_spartans vs Away - longwood_lancers
# Processed game_2022_4482: Home - cornell_big_red vs Away - pennsylvania_quakers
# Processed game_2022_4501: Home - missouri_tigers vs Away - kentucky_wildcats
# Skipping game_2022_453 - missing home or away team
# Processed game_2022_4537: Home - idaho_state_bengals vs Away - northern_arizona_lumberjacks
# Processed game_2022_4538: Home - idaho_vandals vs Away - sacramento_state_hornets
# Processed game_2022_4578: Home - louisiana_tech_lady_techsters vs Away - rice_owls
# Processed game_2022_4579: Home - marshall_thundering_herd vs Away - middle_tennessee_blue_raiders
# Processed game_2022_4581: Home - murray_state_racers vs Away - belmont_bruins
# Processed game_2022_4594: Home - delaware_blue_hens vs Away - elon_phoenix
# Processed game_2022_4597: Home - drexel_dragons vs Away - william_mary_tribe
# Processed game_2022_4602: Home - uconn_huskies vs Away - st_johns_red_storm
# Processed game_2022_4603: Home - butler_bulldogs vs Away - villanova_wildcats
# Processed game_2022_4604: Home - depaul_blue_demons vs Away - seton_hall_pirates
# Processed game_2022_4614: Home - kent_state_golden_flashes vs Away - buffalo_bulls
# Processed game_2022_463: Home - virginia_cavaliers vs Away - ucf_knights
# Processed game_2022_4633: Home - southern_illinois_salukis vs Away - evansville_purple_aces
# Processed game_2022_4635: Home - st_bonaventure_bonnies vs Away - george_mason_patriots
# Processed game_2022_4642: Home - ualbany_great_danes vs Away - stony_brook_seawolves
# Processed game_2022_4652: Home - idaho_vandals vs Away - northern_colorado_bears
# Processed game_2022_4669: Home - quinnipiac_bobcats vs Away - siena_saints
# Processed game_2022_4670: Home - samford_bulldogs vs Away - mercer_bears
# Processed game_2022_4688: Home - california_baptist_lancers vs Away - utah_valley_wolverines
# Processed game_2022_4701: Home - st_francis_pa_red_flash vs Away - sacred_heart_pioneers
# Processed game_2022_4707: Home - louisiana_tech_lady_techsters vs Away - north_texas_mean_green
# Processed game_2022_4714: Home - eastern_illinois_panthers vs Away - austin_peay_governors
# Processed game_2022_4725: Home - navy_midshipmen vs Away - colgate_raiders
# Processed game_2022_4727: Home - southern_jaguars vs Away - bethune_cookman_wildcats
# Processed game_2022_4731: Home - arizona_wildcats vs Away - usc_trojans
# Processed game_2022_4742: Home - ole_miss_rebels vs Away - south_carolina_gamecocks
# Processed game_2022_4751: Home - unc_wilmington_seahawks vs Away - charleston_cougars
# Processed game_2022_4762: Home - north_carolina_tar_heels vs Away - duke_blue_devils
# Processed game_2022_4774: Home - boise_state_broncos vs Away - san_jose_state_spartans
# Processed game_2022_4822: Home - south_florida_bulls vs Away - houston_cougars
# Skipping game_2022_4840 - missing home or away team
# Processed game_2022_485: Home - kansas_jayhawks vs Away - omaha_mavericks
# Skipping game_2022_4850 - missing home or away team
# Skipping game_2022_4851 - missing home or away team
# Skipping game_2022_4853 - missing home or away team
# Processed game_2022_4863: Home - unc_wilmington_seahawks vs Away - northeastern_huskies
# Processed game_2022_4871: Home - uc_san_diego_tritons vs Away - cal_state_bakersfield_roadrunners
# Processed game_2022_4873: Home - niagara_purple_eagles vs Away - iona_gaels
# Processed game_2022_4883: Home - rice_owls vs Away - utep_miners
# Processed game_2022_4892: Home - merrimack_warriors vs Away - wagner_seahawks
# Processed game_2022_49: Home - tcu_horned_frogs vs Away - houston_christian_huskies
# Processed game_2022_4902: Home - elon_phoenix vs Away - william_mary_tribe
# Processed game_2022_4913: Home - iu_indianapolis_jaguars vs Away - robert_morris_colonials
# Skipping game_2022_4922 - missing home or away team
# Skipping game_2022_4925 - missing home or away team
# Processed game_2022_4932: Home - southern_utah_thunderbirds vs Away - weber_state_wildcats
# Processed game_2022_4933: Home - northern_arizona_lumberjacks vs Away - idaho_vandals
# Skipping game_2022_4948 - missing home or away team
# Skipping game_2022_4955 - missing home or away team
# Skipping game_2022_4964 - missing home or away team
# Processed game_2022_497: Home - byu_cougars vs Away - arizona_state_sun_devils
# Processed game_2022_4973: Home - charleston_cougars vs Away - northeastern_huskies
# Skipping game_2022_5023 - missing home or away team
# Processed game_2022_503: Home - georgia_southern_eagles vs Away - florida_international_panthers
# Processed game_2022_5047: Home - baylor_bears vs Away - texas_tech_lady_raiders
# Skipping game_2022_5048 - missing home or away team
# Processed game_2022_505: Home - san_jose_state_spartans vs Away - santa_clara_broncos
# Processed game_2022_507: Home - providence_friars vs Away - rhode_island_rams
# Skipping game_2022_5093 - missing home or away team
# Skipping game_2022_5096 - missing home or away team
# Skipping game_2022_5106 - missing home or away team
# Processed game_2022_5111: Home - ualbany_great_danes vs Away - vermont_catamounts
# Skipping game_2022_5113 - missing home or away team
# Skipping game_2022_5120 - missing home or away team
# Skipping game_2022_5128 - missing home or away team
# Skipping game_2022_5133 - missing home or away team
# Skipping game_2022_5164 - missing home or away team
# Skipping game_2022_5173 - missing home or away team
# Skipping game_2022_5178 - missing home or away team
# Skipping game_2022_5193 - missing home or away team
# Processed game_2022_520: Home - ohio_state_buckeyes vs Away - bowling_green_falcons
# Skipping game_2022_5217 - missing home or away team
# Processed game_2022_54: Home - air_force_falcons vs Away - denver_pioneers
# Processed game_2022_544: Home - houston_christian_huskies vs Away - hartford_hawks
# Processed game_2022_550: Home - oakland_golden_grizzlies vs Away - youngstown_state_penguins
# Skipping game_2022_599 - missing home or away team
# Processed game_2022_61: Home - alabama_crimson_tide vs Away - charleston_southern_buccaneers
# Processed game_2022_611: Home - central_arkansas_sugar_bears vs Away - ul_monroe_warhawks
# Processed game_2022_62: Home - florida_gators vs Away - georgia_state_panthers
# Processed game_2022_621: Home - canisius_golden_griffins vs Away - colgate_raiders
# Processed game_2022_659: Home - brown_bears vs Away - wagner_seahawks
# Processed game_2022_706: Home - oral_roberts_golden_eagles vs Away - tulsa_golden_hurricane
# Processed game_2022_707: Home - creighton_bluejays vs Away - south_dakota_state_jackrabbits
# Skipping game_2022_733 - missing home or away team
# Skipping game_2022_739 - missing home or away team
# Processed game_2022_741: Home - wisconsin_badgers vs Away - chicago_state_cougars
# Processed game_2022_743: Home - mississippi_state_bulldogs vs Away - bethune_cookman_wildcats
# Processed game_2022_766: Home - cal_poly_mustangs vs Away - louisville_cardinals
# Processed game_2022_776: Home - canisius_golden_griffins vs Away - detroit_mercy_titans
# Processed game_2022_779: Home - kennesaw_state_owls vs Away - chattanooga_mocs
# Processed game_2022_793: Home - duquesne_dukes vs Away - akron_zips
# Processed game_2022_80: Home - ucf_knights vs Away - duquesne_dukes
# Processed game_2022_805: Home - mount_st_marys_mountaineers vs Away - howard_bison
# Skipping game_2022_858 - missing home or away team
# Processed game_2022_880: Home - denver_pioneers vs Away - texas_am_corpus_christi_islanders
# Skipping game_2022_881 - missing home or away team
# Skipping game_2022_882 - missing home or away team
# Skipping game_2022_886 - missing home or away team
# Skipping game_2022_90 - missing home or away team
# Skipping game_2022_911 - missing home or away team
# Processed game_2022_915: Home - southern_miss_lady_eagles vs Away - arkansas_pine_bluff_golden_lions
# Skipping game_2022_918 - missing home or away team
# Processed game_2022_923: Home - minnesota_golden_gophers vs Away - bradley_braves
# Processed game_2022_927: Home - kennesaw_state_owls vs Away - hofstra_pride
# Processed game_2022_945: Home - siena_saints vs Away - duquesne_dukes
# Processed game_2022_950: Home - se_louisiana_lady_lions vs Away - utah_state_aggies
# Skipping game_2022_962 - missing home or away team
# Skipping game_2022_969 - missing home or away team
# Processed game_2022_97: Home - dartmouth_big_green vs Away - rhode_island_rams
# Processed game_2022_974: Home - florida_atlantic_owls vs Away - davidson_wildcats
# Skipping game_2022_983 - missing home or away team
# Skipping game_2022_985 - missing home or away team
# Processed game_2022_989: Home - saint_marys_gaels vs Away - uc_santa_barbara_gauchos
# Processed game_2022_999: Home - harvard_crimson vs Away - boston_university_terriers
#
# Validation Accuracy: 48.46%
# Brier Score: 0.270
